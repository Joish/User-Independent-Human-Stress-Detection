# %%
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_length=[]
label=[]
min_4=[]
max_4=[]
mean_4=[]
std_4=[]
var_4=[]
for i in range(1,10):
    globals()['csv_train_%s' % i]=pd.read_csv('4_class_combination_'+str(i)+'-'+str(5)+'.csv',index_col=0)
    csv_length.append(len(list(globals()['csv_train_%s' % i]['acc'])))
    #print('csv_train_'+str(i)+"['acc']"+",")
    min_4.append(globals()['csv_train_%s' % i]['acc'].min())
    max_4.append(globals()['csv_train_%s' % i]['acc'].max())
    mean_4.append(globals()['csv_train_%s' % i]['acc'].mean())
    std_4.append(globals()['csv_train_%s' % i]['acc'].std())
    var_4.append(globals()['csv_train_%s' % i]['acc'].var())
    label.append(str(i)+','+str(15-i)+','+str(csv_length[i-1]))
    #print ('4_class_combination_'+str(i)+'-'+str(15-i)+'.csv')
csv_list_4_class=[csv_train_1['acc'],
csv_train_2['acc'],
csv_train_3['acc'],
csv_train_4['acc'],
csv_train_5['acc'],
csv_train_6['acc'],
csv_train_7['acc'],
csv_train_8['acc'],
csv_train_9['acc'],
csv_train_10['acc'],
csv_train_11['acc'],
csv_train_12['acc'],
csv_train_13['acc'],
csv_train_14['acc'],]

fig = plt.figure()
fig.suptitle('4_class', fontsize=20)
plt.boxplot(csv_list_4_class,labels=label)#
plt.figure(figsize=(5,15))
fig_size = plt.rcParams["figure.figsize"]
print ("Current size:", fig_size)
fig_size[0] = 15
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [6.0, 4.0]

# %%
# Out:
# ['1,14,15',
#  '2,13,105',
#  '3,12,455',
#  '4,11,1365',
#  '5,10,3003',
#  '6,9,5005',
#  '7,8,6435',
#  '8,7,6435',
#  '9,6,5005',
#  '10,5,3003',
#  '11,4,1365',
#  '12,3,455',
#  '13,2,105',
#  '14,1,15']

# %%
df=pd.read_csv('4_class_combination_'+str(7)+'-'+str(8)+'.csv',index_col=0)
max=df['acc'].max()
df[df['acc']==max]
# Out:
#             subjects_in_train               subjects_in_test       acc
# 4939  [4, 5, 7, 8, 9, 11, 17]  [2, 3, 6, 10, 13, 14, 15, 16]  0.838323

# %%
# for i in range(len(min_)):
#     print(max_[i],min_[i],mean_[i],std_[i],var_[i])
fig = plt.figure()
fig.suptitle('4_class', fontsize=20)    
plt.plot(max_4,label = "maximum")
plt.plot(min_4,label = "minimum")
plt.plot(mean_4,label = "mean")
plt.legend()

# %%
fig = plt.figure()
fig.suptitle('4_class', fontsize=20)    
plt.plot(std_4,label = "standard deviation")
plt.plot(var_4,label = "variance")
plt.legend()

# %%
csv_length=[]
label=[]
min_3=[]
max_3=[]
mean_3=[]
std_3=[]
var_3=[]
for i in range(1,10):
    globals()['csv_train_%s' % i]=pd.read_csv('/home/sf/fresh_start/10-5 extra tree/3_class_combination_'+str(i)+'-'+str(5)+'.csv',index_col=0)
    csv_length.append(len(list(globals()['csv_train_%s' % i]['acc'])))
    #print('csv_train_'+str(i)+"['acc']"+",")
    min_3.append(globals()['csv_train_%s' % i]['acc'].min())
    max_3.append(globals()['csv_train_%s' % i]['acc'].max())
    mean_3.append(globals()['csv_train_%s' % i]['acc'].mean())
    std_3.append(globals()['csv_train_%s' % i]['acc'].std())
    var_3.append(globals()['csv_train_%s' % i]['acc'].var())
    label.append(str(i)+','+str(5)+','+str(csv_length[i-1]))
    #print ('4_class_combination_'+str(i)+'-'+str(15-i)+'.csv')
csv_list_3_class=[csv_train_1['acc'],
csv_train_2['acc'],
csv_train_3['acc'],
csv_train_4['acc'],
csv_train_5['acc'],
csv_train_6['acc'],
csv_train_7['acc'],
csv_train_8['acc'],
csv_train_9['acc'],]
# csv_train_10['acc'],
# csv_train_11['acc'],
# csv_train_12['acc'],
# csv_train_13['acc'],
# csv_train_14['acc'],]

fig = plt.figure()
fig.suptitle('3_class', fontsize=20)
plt.boxplot(csv_list_3_class,labels=label)#
plt.figure(figsize=(5,15))
fig_size = plt.rcParams["figure.figsize"]
print ("Current size:", fig_size)
fig_size[0] = 15
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [15.0, 10.0]

# %%
fig = plt.figure()
fig.suptitle('3_class', fontsize=20)    
plt.plot(max_3,label = "maximum")
plt.plot(min_3,label = "minimum")
plt.plot(mean_3,label = "mean")
plt.legend()

# %%
fig = plt.figure()
fig.suptitle('3_class', fontsize=20)    
plt.plot(std_3,label = "standard deviation")
plt.plot(var_3,label = "variance")
plt.legend()

# %%
csv_length=[]
label=[]
min_2=[]
max_2=[]
mean_2=[]
std_2=[]
var_2=[]
for i in range(1,15):
    globals()['csv_train_%s' % i]=pd.read_csv('2_class_combination_'+str(i)+'-'+str(15-i)+'.csv',index_col=0)
    csv_length.append(len(list(globals()['csv_train_%s' % i]['acc'])))
    #print('csv_train_'+str(i)+"['acc']"+",")
    min_2.append(globals()['csv_train_%s' % i]['acc'].min())
    max_2.append(globals()['csv_train_%s' % i]['acc'].max())
    mean_2.append(globals()['csv_train_%s' % i]['acc'].mean())
    std_2.append(globals()['csv_train_%s' % i]['acc'].std())
    var_2.append(globals()['csv_train_%s' % i]['acc'].var())
    label.append(str(i)+','+str(15-i)+','+str(csv_length[i-1]))
    #print ('4_class_combination_'+str(i)+'-'+str(15-i)+'.csv')
csv_list_2_class=[csv_train_1['acc'],
csv_train_2['acc'],
csv_train_3['acc'],
csv_train_4['acc'],
csv_train_5['acc'],
csv_train_6['acc'],
csv_train_7['acc'],
csv_train_8['acc'],
csv_train_9['acc'],
csv_train_10['acc'],
csv_train_11['acc'],
csv_train_12['acc'],
csv_train_13['acc'],
csv_train_14['acc'],]

fig = plt.figure()
fig.suptitle('2_class', fontsize=20)
plt.boxplot(csv_list_2_class,labels=label)#
plt.figure(figsize=(5,15))
fig_size = plt.rcParams["figure.figsize"]
print ("Current size:", fig_size)
fig_size[0] = 15
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [15.0, 10.0]

# %%
fig = plt.figure()
fig.suptitle('2_class', fontsize=20)    
plt.plot(max_2,label = "maximum")
plt.plot(min_2,label = "minimum")
plt.plot(mean_2,label = "mean")
plt.legend()

# %%
fig = plt.figure()
fig.suptitle('2_class', fontsize=20)    
plt.plot(std_2,label = "standard deviation")
plt.plot(var_2,label = "variance")
plt.legend()

# %%
label
# Out:
# ['1,14,15',
#  '2,13,105',
#  '3,12,455',
#  '4,11,1365',
#  '5,10,3003',
#  '6,9,5005',
#  '7,8,6435',
#  '8,7,6435',
#  '9,6,5005',
#  '10,5,3003',
#  '11,4,1365',
#  '12,3,455',
#  '13,2,105',
#  '14,1,15']

# %%
master_list=[]
for i in range(2,5):
    print(i)
    class_split=globals()['csv_list_%s_class' % i]
    for j in range(len(class_split)):
        for k in class_split[j]:
            master_list.append([k,str(i)+"_class",label[j]])

print(len(master_list))
master_list
# Out:
# 2
# 3
# 4
# 98298
# [[0.8254237288135593, '2_class', '1,14,15'],
#  [0.7534013605442177, '2_class', '1,14,15'],
#  [0.8683760683760684, '2_class', '1,14,15'],
#  [0.8373287671232876, '2_class', '1,14,15'],
#  [0.8519793459552496, '2_class', '1,14,15'],
#  [0.8709122203098106, '2_class', '1,14,15'],
#  [0.852991452991453, '2_class', '1,14,15'],
#  [0.865979381443299, '2_class', '1,14,15'],
#  [0.8591304347826086, '2_class', '1,14,15'],
#  [0.8460207612456747, '2_class', '1,14,15'],
#  [0.8848167539267016, '2_class', '1,14,15'],
#  [0.8717948717948718, '2_class', '1,14,15'],
#  [0.8681506849315068, '2_class', '1,14,15'],
#  [0.8630849220103987, '2_class', '1,14,15'],
#  [0.12244897959183673, '2_class', '1,14,15'],
#  [0.8212996389891697, '2_class', '2,13,105'],
#  [0.8058076225045372, '2_class', '2,13,105'],
#  [0.8054545454545454, '2_class', '2,13,105'],
#  [0.8098720292504571, '2_class', '2,13,105'],
#  [0.8555758683729433, '2_class', '2,13,105'],
# ...

# %%
df=pd.DataFrame(master_list,columns=['acc','no_of_class','split'])
df
# Out:
#             acc no_of_class    split
# 0      0.825424     2_class  1,14,15
# 1      0.753401     2_class  1,14,15
# 2      0.868376     2_class  1,14,15
# 3      0.837329     2_class  1,14,15
# 4      0.851979     2_class  1,14,15
# ...         ...         ...      ...
# 98293  0.835294     4_class  14,1,15
# 98294  0.850000     4_class  14,1,15
# 98295  0.628205     4_class  14,1,15
# 98296  0.640000     4_class  14,1,15
# 98297  0.850000     4_class  14,1,15
#
# [98298 rows x 3 columns]

# %%
sns.boxplot(x="split", y="acc", hue="no_of_class",data=df, palette="BrBG")
plt.ylabel('accuracy')
plt.xlabel('train_subject,test_subject,no of models developed')
# Out:
# Text(0.5, 0, 'train_subject,test_subject,no of models developed')

# %%
plt.figure(figsize=(5,15))
fig_size = plt.rcParams["figure.figsize"]
print ("Current size:", fig_size)
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [15.0, 10.0]

# %%
fig = plt.figure()
fig.suptitle('max,mean,min', fontsize=20)    
plt.plot(max_2,label = "maximum_of_2_class",linewidth=3,color='brown')
plt.plot(max_3,label = "maximum_of_3_class",linewidth=3,color='green')
plt.plot(max_4,label = "maximum_of_4_class",linewidth=3,color='blue')

plt.plot(mean_2,label = "mean_of_2_class",marker='o',color='brown')
plt.plot(mean_3,label = "mean_of_3_class",marker='o',color='green')
plt.plot(mean_4,label = "mean_of_4_class",marker='o',color='blue')

plt.plot(min_2,label = "minimum_of_2_class",linestyle='dashed',color='brown')
plt.plot(min_3,label = "minimum_of_3_class",linestyle='dashed',color='green')
plt.plot(min_4,label = "minimum_of_4_class",linestyle='dashed',color='blue')


#leg1 = plt.legend(loc='lower left')


plt.ylabel('accuracy')
plt.xlabel('train_subject,test_subject,no of models')
plt.xticks(range(14), label)
plt.legend() 
#plt.add_artist(leg1)

# %%
len(max_2)
# Out:
# 14

# %%
def delta(t):
    ret = [j-i for i, j in zip(t[:-1], t[1:])]
    return ret

# %%
max_2_delta = delta(max_2)

# %%
print(len(max_2_delta))
# Out:
# 13

# %%
(delta(min_3))
# Out:
# [0.11446334691948729,
#  0.04958988380041013,
#  -0.010488944483278806,
#  0.13383724727083385,
#  0.04713575860559727,
#  -0.004142519118000121,
#  -0.02182799130998836,
#  -0.003007963529343849,
#  -0.003331352911220553,
#  -0.03456045699777843,
#  0.00807453416149062,
#  -0.0028571428571427804,
#  -0.028888888888888964]

# %%
fig = plt.figure()
fig.suptitle('max,mean,min', fontsize=20)    
#plt.plot(delta(max_2),label = "maximum_of_2_class",linewidth=3,color='brown')
#plt.plot(delta(max_3),label = "maximum_of_3_class",linewidth=3,color='green')
#plt.plot(delta(max_4),label = "maximum_of_4_class",linewidth=3,color='blue')

plt.plot(delta(mean_2),label = "mean_of_2_class",marker='o',color='brown')
plt.plot(delta(mean_3),label = "mean_of_3_class",marker='o',color='green')
plt.plot(delta(mean_4),label = "mean_of_4_class",marker='o',color='blue')

plt.plot(delta(min_2),label = "minimum_of_2_class",linestyle='dashed',color='brown')
plt.plot(delta(min_3),label = "minimum_of_3_class",linestyle='dashed',color='green')
plt.plot(delta(min_4),label = "minimum_of_4_class",linestyle='dashed',color='blue')


#leg1 = plt.legend(loc='lower left')


plt.ylabel('accuracy')
#plt.ylim(-., 1.5)
#plt.set_ticks([0., 0.125, .05])
plt.xlabel('train_subject,test_subject,no of models')
plt.xticks(range(14),)
plt.legend() 
#plt.add_artist(leg1)

# %%
max_min_2=[]
max_min_3=[]
max_min_4=[]
mean_min_2=[]
mean_min_3=[]
mean_min_4=[]
for i in range(len(max_2)):
    max_min_2.append(max_2[i]-min_2[i])
    max_min_3.append(max_3[i]-min_3[i])
    max_min_4.append(max_4[i]-min_4[i])
    mean_min_2.append(mean_2[i]-min_2[i])
    mean_min_3.append(mean_3[i]-min_3[i])
    mean_min_4.append(mean_4[i]-min_4[i])
max_min_2
# Out:
# [0.7623677743348648,
#  0.33269861419655133,
#  0.1747435528712492,
#  0.14791498984324103,
#  0.19079083331419766,
#  0.210285578196031,
#  0.21832715695420357,
#  0.22839912280701757,
#  0.24751718869365913,
#  0.2937490084086942,
#  0.36242138364779874,
#  0.43241350329177775,
#  0.47560975609756106,
#  0.6111111111111112]

# %%
#.bar
fig = plt.figure()
fig.suptitle('max,mean,min', fontsize=20)    

plt.plot(max_min_2,label = "range between max and min 2 class",marker='o',color='brown')
plt.plot(max_min_3,label = "range between max and min 3 class",marker='o',color='green')
plt.plot(max_min_4,label = "range between max and min 4 class",marker='o',color='blue')
#
plt.plot(mean_min_2,label = "range between mean and min 2 class",linestyle='dashed',color='brown')
plt.plot(mean_min_3,label = "range between mean and min 3 class",linestyle='dashed',color='green')
plt.plot(mean_min_4,label = "range between mean and min 4 class",linestyle='dashed',color='blue')


#leg1 = plt.legend(loc='lower left')


plt.ylabel('accuracy')
#plt.ylim(-., 1.5)
#plt.set_ticks([0., 0.125, .05])
plt.xlabel('train_subject,test_subject,no of models')
plt.xticks(range(14),)
#plt.xlim(4,9)
plt.legend() 
#plt.add_artist(leg1)

# %%
#.bar
fig = plt.figure()
fig.suptitle('max,mean,min', fontsize=20)    

plt.bar(max_min_2,label = "range between max and min 2 class",marker='o',color='brown')
plt.bar(max_min_3,label = "range between max and min 3 class",marker='o',color='green')
plt.bar(max_min_3,label = "range between max and min 4 class",marker='o',color='blue')

plt.bar(mean_min_2,label = "range between mean and min 2 class",linestyle='dashed',color='brown')
plt.bar(mean_min_3,label = "range between mean and min 3 class",linestyle='dashed',color='green')
plt.bar(mean_min_4,label = "range between mean and min 4 class",linestyle='dashed',color='blue')


#leg1 = plt.legend(loc='lower left')


plt.ylabel('accuracy')
#plt.ylim(-., 1.5)
#plt.set_ticks([0., 0.125, .05])
plt.xlabel('train_subject,test_subject,no of models')
plt.xticks(range(14),)
plt.legend() 
#plt.add_artist(leg1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-dea35e696d40> in <module>
#       3 fig.suptitle('max,mean,min', fontsize=20)
#       4
# ----> 5 plt.bar(max_min_2,label = "range between max and min 2 class",marker='o',color='brown')
#       6 plt.bar(max_min_3,label = "range between max and min 3 class",marker='o',color='green')
#       7 plt.bar(max_min_4,label = "range between max and min 4 class",marker='o',color='blue')
#
# TypeError: bar() missing 1 required positional argument: 'height'
