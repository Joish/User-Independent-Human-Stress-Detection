# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv("master_data.csv")
df
# Out:
# CPU times: user 44.7 s, sys: 6.46 s, total: 51.1 s
# Wall time: 51.1 s
#           target  subject  chest_ACC_x  chest_ACC_y  chest_ACC_z  chest_ECG  \
# 0              1        6       0.6280      -0.0082      -0.7272   0.016937
# 1              1        6       0.6276      -0.0056      -0.7262   0.017853
# 2              1        6       0.6270      -0.0054      -0.7200   0.016525
# 3              1        6       0.6266      -0.0070      -0.7174   0.012863
# 4              1        6       0.6242      -0.0078      -0.7202   0.007278
# ...          ...      ...          ...          ...          ...        ...
# 31470598       4        7       0.8442      -0.0344      -0.3638  -0.076309
# 31470599       4        7       0.8434      -0.0330      -0.3634  -0.074844
# 31470600       4        7       0.8462      -0.0348      -0.3650  -0.073013
# 31470601       4        7       0.8446      -0.0360      -0.3652  -0.071136
# ...

# %%
df = df[df['target']>0]

# %%
df
# Out:
#           target  subject  chest_ACC_x  chest_ACC_y  chest_ACC_z  chest_ECG  \
# 0              1        6       0.6280      -0.0082      -0.7272   0.016937
# 1              1        6       0.6276      -0.0056      -0.7262   0.017853
# 2              1        6       0.6270      -0.0054      -0.7200   0.016525
# 3              1        6       0.6266      -0.0070      -0.7174   0.012863
# 4              1        6       0.6242      -0.0078      -0.7202   0.007278
# ...          ...      ...          ...          ...          ...        ...
# 31470598       4        7       0.8442      -0.0344      -0.3638  -0.076309
# 31470599       4        7       0.8434      -0.0330      -0.3634  -0.074844
# 31470600       4        7       0.8462      -0.0348      -0.3650  -0.073013
# 31470601       4        7       0.8446      -0.0360      -0.3652  -0.071136
# 31470602       4        7       0.8472      -0.0358      -0.3654  -0.067154
#
#           chest_EMG  chest_EDA  chest_Temp  chest_Resp
# ...

# %%
df['target'].unique()
# Out:
# array([1, 2, 4, 3])

# %%
df.to_csv("master_data.csv",index=False)

# %%
df
